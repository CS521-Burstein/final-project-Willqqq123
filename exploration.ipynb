# %%
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/bursteinalan/Data-Sets/master/Housing/House%20Prediction%20Data.csv"

# %%
df = pd.read_csv(url)

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal   208500.0
# 1   2007        WD         Normal   181500.0
# 2   2008        WD         Normal   223500.0
# 3   2006        WD        Abnorml   140000.0
# 4   2008        WD         Normal   250000.0
#
# [5 rows x 81 columns]

# %%
df.shape
# Out:
# (2919, 81)

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  2919.000000  2919.000000  2433.000000    2919.000000  2919.000000
# mean   1460.000000    57.137718    69.305795   10168.114080     6.089072
# std     842.787043    42.517628    23.344905    7886.996359     1.409947
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     730.500000    20.000000    59.000000    7478.000000     5.000000
# 50%    1460.000000    50.000000    68.000000    9453.000000     6.000000
# 75%    2189.500000    70.000000    80.000000   11570.000000     7.000000
# max    2919.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  2919.000000  2919.000000   2919.000000  2896.000000  2918.000000  ...
# mean      5.564577  1971.312778   1984.264474   102.201312   441.423235  ...
# std       1.113131    30.291442     20.894344   179.334253   455.610826  ...
# min       1.000000  1872.000000   1950.000000     0.000000     0.000000  ...
# 25%       5.000000  1953.500000   1965.000000     0.000000     0.000000  ...
# 50%       5.000000  1973.000000   1993.000000     0.000000   368.500000  ...
# 75%       6.000000  2001.000000   2004.000000   164.000000   733.000000  ...
# max       9.000000  2010.000000   2010.000000  1600.000000  5644.000000  ...
#
#         WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  ScreenPorch  \
# count  2919.000000  2919.000000    2919.000000  2919.000000  2919.000000
# mean     93.709832    47.486811      23.098321     2.602261    16.062350
# std     126.526589    67.575493      64.244246    25.188169    56.184365
# min       0.000000     0.000000       0.000000     0.000000     0.000000
# 25%       0.000000     0.000000       0.000000     0.000000     0.000000
# 50%       0.000000    26.000000       0.000000     0.000000     0.000000
# 75%     168.000000    70.000000       0.000000     0.000000     0.000000
# max    1424.000000   742.000000    1012.000000   508.000000   576.000000
#
#           PoolArea       MiscVal       MoSold       YrSold      SalePrice
# count  2919.000000   2919.000000  2919.000000  2919.000000    1460.000000
# mean      2.251799     50.825968     6.213087  2007.792737  180921.195890
# std      35.663946    567.402211     2.714762     1.314964   79442.502883
# min       0.000000      0.000000     1.000000  2006.000000   34900.000000
# 25%       0.000000      0.000000     4.000000  2007.000000  129975.000000
# 50%       0.000000      0.000000     6.000000  2008.000000  163000.000000
# 75%       0.000000      0.000000     8.000000  2009.000000  214000.000000
# max     800.000000  17000.000000    12.000000  2010.000000  755000.000000
#
# [8 rows x 38 columns]

# %%
df.groupby('Street').describe()
# Out:
#             Id                                                                 \
#          count         mean         std   min    25%     50%      75%     max
# Street
# Grvl      12.0  1421.166667  884.029908  53.0  755.5  1394.0  2151.75  2894.0
# Pave    2907.0  1460.160303  842.768406   1.0  730.5  1460.0  2189.50  2919.0
#
#        MSSubClass             ...   YrSold         SalePrice                 \
#             count       mean  ...      75%     max     count           mean
# Street                        ...
# Grvl         12.0  55.833333  ...  2009.25  2010.0       6.0  130190.500000
# Pave       2907.0  57.143103  ...  2009.00  2010.0    1454.0  181130.538514
#
#
#                  std      min       25%       50%       75%       max
# Street
# Grvl    65446.253991  55993.0   88250.0  114250.0  169650.0  228950.0
# Pave    79446.597317  34900.0  130000.0  163000.0  214000.0  755000.0
#
# [2 rows x 304 columns]

# %%
df.isna().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            4
# LotFrontage       486
# LotArea             0
#                  ...
# MoSold              0
# YrSold              0
# SaleType            1
# SaleCondition       0
# SalePrice        1459
# Length: 81, dtype: int64

# %%
df=df.dropna(axis=0,subset = ['LotArea','SalePrice'])

# %%
df.isna().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
df.sort_values(by='LotArea')
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 956    957         160       RM         24.0     1300   Pave   NaN      Reg
# 1039  1040         180       RM         21.0     1477   Pave   NaN      Reg
# 614    615         180       RM         21.0     1491   Pave   NaN      Reg
# 489    490         180       RM         21.0     1526   Pave   NaN      Reg
# 1449  1450         180       RM         21.0     1533   Pave   NaN      Reg
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 451    452          20       RL         62.0    70761   Pave   NaN      IR1
# 706    707          20       RL          NaN   115149   Pave   NaN      IR2
# 249    250          50       RL          NaN   159000   Pave   NaN      IR2
# 335    336         190       RL          NaN   164660   Grvl   NaN      IR1
# 313    314          20       RL        150.0   215245   Pave   NaN      IR3
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 956          Lvl    AllPub  ...        0    NaN  GdPrv         NaN       0
# 1039         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 614          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 489          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1449         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...          ...       ...  ...      ...    ...    ...         ...     ...
# 451          Low    AllPub  ...        0    NaN    NaN         NaN       0
# 706          Low    AllPub  ...        0    NaN    NaN         NaN       0
# 249          Low    AllPub  ...        0    NaN    NaN        Shed     500
# 335          HLS    AllPub  ...        0    NaN    NaN        Shed     700
# 313          Low    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 956       5   2009        WD         Normal   124000.0
# 1039      4   2009        WD         Normal    80000.0
# 614       5   2010        WD         Normal    75500.0
# 489       5   2009        WD         Normal    86000.0
# 1449      8   2006        WD        Abnorml    92000.0
# ...     ...    ...       ...            ...        ...
# 451      12   2006        WD         Normal   280000.0
# 706       6   2007        WD         Normal   302000.0
# 249       6   2007        WD         Normal   277000.0
# 335       8   2008        WD         Normal   228950.0
# 313       6   2009        WD         Normal   375000.0
#
# [1460 rows x 81 columns]

# %%
df['MSZoning'].unique()
# Out:
# array(['RL', 'RM', 'C (all)', 'FV', 'RH'], dtype=object)

# %%
print('{:.2%}'.format((df['MSZoning']=='RL').sum()/df.shape[0]))
# Out:
# 78.38%

# %%
print('{:.2%}'.format((df['LotShape']=='Reg').sum()/df.shape[0]))
# Out:
# 64.31%

# %%
df=df.drop(columns=['Id'],axis=1)

# %%
df=df.drop(df[df['LotArea']>25000].index)

# %%
df.plot.scatter('LotArea','SalePrice')
# Out:
# <AxesSubplot:xlabel='LotArea', ylabel='SalePrice'>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
plt.hist(df['LotArea'],bins=7)
# Out:
# (array([135., 306., 641., 250.,  66.,  18.,  13.]),
#  array([ 1300.        ,  4685.71428571,  8071.42857143, 11457.14285714,
#         14842.85714286, 18228.57142857, 21614.28571429, 25000.        ]),
#  <BarContainer object of 7 artists>)

# %%
sns.histplot(data=df,x='MSZoning',hue='LotShape',multiple='stack',bins=7,edgecolor='green')
# Out:
# <AxesSubplot:xlabel='MSZoning', ylabel='Count'>

# %%
sns.countplot(data=df,x='YrSold',order = df['YrSold'].value_counts().index)
# Out:
# <AxesSubplot:xlabel='YrSold', ylabel='count'>

# %%
sns.barplot(x='YrSold', y='SalePrice', data=df);

# %%
y=df['SalePrice']
X=df[['YrSold','LotArea']]

# %%
from sklearn.linear_model import LinearRegression
from sklearn import metrics
regressor = LinearRegression()
regressor.fit(X, y)
coef_df = pd.DataFrame(regressor.coef_, X.columns, columns=['Coefficient'])
coef_df
#It indicates that standardized treatment is required
# Out:
#          Coefficient
# YrSold   -739.527221
# LotArea     8.858682

# %%
dummy = pd.get_dummies(df[['MSZoning','LotShape']])

# %%
df.corr()
# Out:
#                MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  \
# MSSubClass       1.000000    -0.431251 -0.394600     0.038108    -0.056897
# LotFrontage     -0.431251     1.000000  0.662644     0.241809    -0.064436
# LotArea         -0.394600     0.662644  1.000000     0.218100    -0.013178
# OverallQual      0.038108     0.241809  0.218100     1.000000    -0.091338
# OverallCond     -0.056897    -0.064436 -0.013178    -0.091338     1.000000
# YearBuilt        0.027433     0.138984  0.068745     0.575571    -0.379387
# YearRemodAdd     0.045348     0.085923  0.051274     0.551939     0.066175
# MasVnrArea       0.025557     0.184191  0.136061     0.402252    -0.128244
# BsmtFinSF1      -0.079835     0.148443  0.164908     0.220618    -0.034622
# BsmtFinSF2      -0.063572     0.044841  0.077280    -0.063929     0.039952
# BsmtUnfSF       -0.139452     0.168482  0.117646     0.316212    -0.140563
# TotalBsmtSF     -0.256647     0.350346  0.326568     0.543408    -0.171453
# 1stFlrSF        -0.263575     0.406678  0.420829     0.476678    -0.143335
# 2ndFlrSF         0.314341     0.074710  0.125779     0.282423     0.032263
# LowQualFinSF     0.045469     0.016951  0.021521    -0.038957     0.034351
# GrLivArea        0.081482     0.363708  0.419762     0.589993    -0.074263
# BsmtFullBath     0.002120     0.055750  0.074110     0.101070    -0.049793
# BsmtHalfBath    -0.001416    -0.018272  0.029815    -0.039718     0.125182
# FullBath         0.136377     0.203871  0.205122     0.554661    -0.198803
# HalfBath         0.181344     0.063708  0.108810     0.266670    -0.057584
# WoodDeckSF      0.232176      0.216610    0.147603    0.179734    0.069000
# OpenPorchSF     0.183655      0.226909    0.098599    0.067086    0.015898
# EnclosedPorch  -0.388422     -0.202806   -0.108214   -0.113712    0.036632
# 3SsnPorch       0.031218      0.045701    0.021161    0.032297   -0.029895
# ScreenPorch    -0.049314     -0.038164    0.062426    0.067184    0.085692
# PoolArea        0.011577     -0.006248   -0.016343    0.045193    0.042995
# MiscVal        -0.034413     -0.010155   -0.030783    0.004405    0.005478
# MoSold          0.011903      0.017179   -0.004716    0.001620   -0.011996
# YrSold         -0.015231      0.038288   -0.000610    0.023027    0.023400
# SalePrice       0.535413      0.519001    0.469212    0.394686   -0.022255
#
#                ...  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# MSSubClass     ...   -0.029166    -0.000256      -0.012883  -0.044764
# LotFrontage    ...    0.102665     0.139828      -0.012912   0.082358
# LotArea        ...    0.157122     0.152528      -0.009276   0.087380
# OverallQual    ...    0.238012     0.304888      -0.125061   0.031499
# OverallCond    ...   -0.002526    -0.028065       0.086301   0.025687
# YearBuilt      ...    0.232176     0.183655      -0.388422   0.031218
# YearRemodAdd   ...    0.216610     0.226909      -0.202806   0.045701
# MasVnrArea     ...    0.147603     0.098599      -0.108214   0.021161
# BsmtFinSF1     ...    0.179734     0.067086      -0.113712   0.032297
# BsmtFinSF2     ...    0.069000     0.015898       0.036632  -0.029895
# BsmtUnfSF      ...    0.011452     0.128054      -0.001103   0.019841
# TotalBsmtSF    ...    0.224768     0.212989      -0.104921   0.043310
# 1stFlrSF       ...    0.227545     0.183890      -0.073917   0.063116
# 2ndFlrSF       ...    0.079949     0.201784       0.055440  -0.024270
# LowQualFinSF   ...   -0.019896     0.022964       0.014213  -0.004032
# GrLivArea      ...    0.234235     0.311236      -0.005197   0.025093
# BsmtFullBath   ...    0.156241     0.059618      -0.054460   0.002440
# BsmtHalfBath   ...    0.042259    -0.030091      -0.031397   0.036688
# FullBath       ...    0.191668     0.261597      -0.130126   0.037113
# HalfBath       ...    0.101248     0.191615      -0.091654  -0.005164
# BedroomAbvGr   ...    0.051514     0.096852       0.032937  -0.024260
# KitchenAbvGr   ...   -0.087540    -0.068252       0.029942  -0.024940
# TotRmsAbvGrd   ...    0.158385     0.226247      -0.001324  -0.005395
# Fireplaces     ...    0.195209     0.159155      -0.026663   0.014484
# GarageYrBlt    ...    0.240676     0.228431      -0.296917   0.023005
# GarageCars     ...    0.212681     0.210552      -0.156748   0.037596
# GarageArea     ...    0.209362     0.231737      -0.133079   0.037956
# WoodDeckSF     ...    1.000000     0.055523      -0.119114  -0.031480
# OpenPorchSF    ...    0.055523     1.000000      -0.089219  -0.004903
# EnclosedPorch  ...   -0.119114    -0.089219       1.000000  -0.038191
# 3SsnPorch      ...   -0.031480    -0.004903      -0.038191   1.000000
# ScreenPorch    ...   -0.095090     0.071983      -0.082186  -0.031379
# PoolArea       ...    0.086540     0.040331      -0.021405  -0.006912
# MiscVal        ...   -0.011987    -0.018145       0.019823   0.000330
# MoSold         ...    0.016282     0.074443      -0.022109   0.029235
# YrSold         ...    0.026882    -0.053271      -0.001059   0.018586
# SalePrice      ...    0.303953     0.330007      -0.133533   0.048310
#
#                ScreenPorch  PoolArea   MiscVal    MoSold    YrSold  SalePrice
# MSSubClass